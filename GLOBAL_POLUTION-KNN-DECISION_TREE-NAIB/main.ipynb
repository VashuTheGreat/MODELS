# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Global_Pollution_Analysis.csv')

# %%
data.head()
# Out:
#         Country  Year  Air_Pollution_Index  Water_Pollution_Index  \
# 0       Hungary  2005               272.70                 124.27
# 1     Singapore  2001                86.72                  60.34
# 2       Romania  2016                91.59                  83.36
# 3  Cook Islands  2018               280.61                  67.16
# 4      Djibouti  2008               179.16                 127.53
#
#    Soil_Pollution_Index  Industrial_Waste (in tons)  \
# 0                 51.95                    94802.83
# 1                117.22                    56283.92
# 2                121.72                    56256.02
# 3                 93.58                    74864.73
# 4                121.55                    76862.06
#
#    Energy_Recovered (in GWh)  CO2_Emissions (in MT)  Renewable_Energy (%)  \
# 0                     158.14                   5.30                 41.11
# 1                     498.04                   6.34                 36.44
# ...

# %%
data=data.drop(['Country'],axis=1)

# %%
data.head()
# Out:
#    Year  Air_Pollution_Index  Water_Pollution_Index  Soil_Pollution_Index  \
# 0  2005               272.70                 124.27                 51.95
# 1  2001                86.72                  60.34                117.22
# 2  2016                91.59                  83.36                121.72
# 3  2018               280.61                  67.16                 93.58
# 4  2008               179.16                 127.53                121.55
#
#    Industrial_Waste (in tons)  Energy_Recovered (in GWh)  \
# 0                    94802.83                     158.14
# 1                    56283.92                     498.04
# 2                    56256.02                     489.51
# 3                    74864.73                     145.18
# 4                    76862.06                      40.38
#
#    CO2_Emissions (in MT)  Renewable_Energy (%)  \
# 0                   5.30                 41.11
# 1                   6.34                 36.44
# ...

# %%
data["Pollution_Index"] = (data["Air_Pollution_Index"] + data["Water_Pollution_Index"] + data["Soil_Pollution_Index"]) / 3

# %%
data.head()
# Out:
#    Year  Air_Pollution_Index  Water_Pollution_Index  Soil_Pollution_Index  \
# 0  2005               272.70                 124.27                 51.95
# 1  2001                86.72                  60.34                117.22
# 2  2016                91.59                  83.36                121.72
# 3  2018               280.61                  67.16                 93.58
# 4  2008               179.16                 127.53                121.55
#
#    Industrial_Waste (in tons)  Energy_Recovered (in GWh)  \
# 0                    94802.83                     158.14
# 1                    56283.92                     498.04
# 2                    56256.02                     489.51
# 3                    74864.73                     145.18
# 4                    76862.06                      40.38
#
#    CO2_Emissions (in MT)  Renewable_Energy (%)  \
# 0                   5.30                 41.11
# 1                   6.34                 36.44
# ...

# %%
correlation = data.corr(method='pearson')["Pollution_Index"]
print(correlation)
# Out:
# Year                                      0.033118
# Air_Pollution_Index                       0.739757
# Water_Pollution_Index                     0.496478
# Soil_Pollution_Index                      0.451256
# Industrial_Waste (in tons)                0.101874
# Energy_Recovered (in GWh)                 0.008273
# CO2_Emissions (in MT)                    -0.011397
# Renewable_Energy (%)                     -0.054804
# Plastic_Waste_Produced (in tons)          0.066034
# Energy_Consumption_Per_Capita (in MWh)   -0.050265
# Population (in millions)                  0.060071
# GDP_Per_Capita (in USD)                  -0.011169
# Pollution_Index                           1.000000
# Name: Pollution_Index, dtype: float64

# %%
data=data[['Air_Pollution_Index','Water_Pollution_Index','Soil_Pollution_Index','Pollution_Index']]

# %%
import pandas as pd

# Convert numpy array to pandas DataFrame
data_df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
data_df.head()
# Out:
#    Air_Pollution_Index  Water_Pollution_Index  Soil_Pollution_Index  \
# 0               272.70                 124.27                 51.95
# 1                86.72                  60.34                117.22
# 2                91.59                  83.36                121.72
# 3               280.61                  67.16                 93.58
# 4               179.16                 127.53                121.55
#
#    Pollution_Index
# 0       149.640000
# 1        88.093333
# 2        98.890000
# 3       147.116667
# 4       142.746667

# %%
x=data.drop(['Pollution_Index'],axis=1)
y=data['Pollution_Index']

# %%
def categorize_pollution(pollution_index):
    if pollution_index <= 50:
        return "Low"
    elif pollution_index <= 150:
        return "Medium"
    else:
        return "High"

# %%
data['overall'] = data['Pollution_Index'].apply(categorize_pollution)

# %%
data
# Out:
#      Air_Pollution_Index  Water_Pollution_Index  Soil_Pollution_Index  \
# 0                 272.70                 124.27                 51.95
# 1                  86.72                  60.34                117.22
# 2                  91.59                  83.36                121.72
# 3                 280.61                  67.16                 93.58
# 4                 179.16                 127.53                121.55
# ..                   ...                    ...                   ...
# 195               115.84                  78.75                 42.34
# 196               121.82                 120.97                 63.95
# 197               149.73                 146.92                 37.04
# 198               237.20                 113.63                101.96
# 199               135.50                 158.43                 89.80
#
#      Pollution_Index overall
# 0         149.640000  Medium
# 1          88.093333  Medium
# 2          98.890000  Medium
# ...

# %%
x=data[['Air_Pollution_Index','Water_Pollution_Index','Soil_Pollution_Index']]
y=data['overall']

# %%
x=np.array(x)
y=np.array(y)

# %%
x
# Out:
# array([[272.7 , 124.27,  51.95],
#        [ 86.72,  60.34, 117.22],
#        [ 91.59,  83.36, 121.72],
#        [280.61,  67.16,  93.58],
#        [179.16, 127.53, 121.55],
#        [151.36,  61.07,  86.75],
#        [292.31, 156.85,  36.4 ],
#        [209.41, 188.14, 133.5 ],
#        [269.63,  62.33,  71.19],
#        [231.99, 155.31,  44.99],
#        [255.33,  69.93, 110.09],
#        [286.81,  71.15, 100.44],
#        [104.15,  75.12, 125.98],
#        [201.63,  68.97,  40.88],
#        [167.85, 171.94,  21.09],
#        [170.42, 172.18,  97.55],
#        [104.84,  90.52,  82.33],
#        [152.69, 162.42, 121.99],
#        [ 85.68,  50.38,  95.85],
#        [195.66,  43.34, 107.15],
#        [241.87, 192.48,  48.06],
#        [205.8 , 113.75, 100.78],
#        [177.7 ,  31.13,  84.47],
#        [ 91.93, 175.71,  47.64],
#        [221.4 , 192.86,  36.32],
#        [280.59, 174.16,  19.58],
#        [199.13,  93.1 ,  29.13],
#        [ 67.21,  83.62,  25.45],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB

modelNB=GaussianNB()
modelNB.fit(x_train,y_train)
y_pred=modelNB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

accuracy_score=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy_score)
confusion_matrix=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:",confusion_matrix)
# Out:
# Accuracy: 0.975
# Confusion Matrix: [[ 4  1]
#  [ 0 35]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

k_values=range(1,21)
cv_scores=[]


for i in k_values:
    knn=KNeighborsClassifier(n_neighbors=i)
    scores=cross_val_score(knn,x_train,y_train,cv=5,scoring='accuracy')
    cv_scores.append(scores.mean())
    
plt.figure(figsize=(8, 5))
plt.plot(k_values, cv_scores, marker='o', linestyle='-')
plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Cross-Validation Accuracy")
plt.title("Elbow Method for Optimal K")
plt.xticks(k_values)
plt.grid()
plt.show()


best_k=k_values[np.argmax(cv_scores)]    
print(f"Best K: {best_k}")
# Out:
# c:\Users\Asus\100DaysML\MODELS\GLOBAL_POLUTION-KNN-DECISION_TREE-NAIB\.venv\lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Asus\100DaysML\MODELS\GLOBAL_POLUTION-KNN-DECISION_TREE-NAIB\.venv\lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Asus\100DaysML\MODELS\GLOBAL_POLUTION-KNN-DECISION_TREE-NAIB\.venv\lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Asus\100DaysML\MODELS\GLOBAL_POLUTION-KNN-DECISION_TREE-NAIB\.venv\lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# ...

# %%
modelNB=KNeighborsClassifier(n_neighbors=2)
modelNB.fit(x_train,y_train)
y_pred=modelNB.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.975

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

accuracy_score=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy_score)
confusion_matrix=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:",confusion_matrix)
# Out:
# Accuracy: 0.975
# Confusion Matrix: [[ 5  0]
#  [ 1 34]]

# %%
from sklearn.tree import DecisionTreeClassifier
modelDT=DecisionTreeClassifier()
modelDT.fit(x_train,y_train)
y_pred=modelDT.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# Correct variable names
accuracy = accuracy_score(y_test, y_pred)  # Do not overwrite function name
print("Accuracy:", accuracy)

conf_matrix = confusion_matrix(y_test, y_pred)  # Do not overwrite function name
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.95
# Confusion Matrix:
#  [[ 4  1]
#  [ 1 34]]
