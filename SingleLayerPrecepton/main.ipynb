# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
data=pd.read_csv("cgpa_score_placement_dataset.csv")

# %%
data
# Out:
#          CGPA      Score  placed
# 0    8.123620  75.785730     1.0
# 1    9.852143  90.910260     1.0
# 2    9.195982  82.858900     1.0
# 3    8.795975  87.714267     1.0
# 4    7.468056  97.689162     1.0
# ..        ...        ...     ...
# 195  5.805608  72.576506     0.0
# 196  6.424984  70.044446     0.0
# 197  5.039553  55.014791     0.0
# 198  6.057226  66.280487     0.0
# 199  4.713369  66.409001     0.0
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='CGPA', y='Score', data=data, hue='placed')
plt.show()

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#          CGPA      Score
# 0    8.123620  75.785730
# 1    9.852143  90.910260
# 2    9.195982  82.858900
# 3    8.795975  87.714267
# 4    7.468056  97.689162
# ..        ...        ...
# 195  5.805608  72.576506
# 196  6.424984  70.044446
# 197  5.039553  55.014791
# 198  6.057226  66.280487
# 199  4.713369  66.409001
#
# [200 rows x 2 columns]

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195    0.0
# 196    0.0
# 197    0.0
# 198    0.0
# 199    0.0
# Name: placed, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import Perceptron

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
pr = Perceptron()
pr.fit(x, y.astype(int))  # Train with DataFrame
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100,pr.score(x_test,y_test)*100
# Out:
# (50.625, 47.5)

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy().astype(int), clf=pr, legend=2)
plt.show()
# Out:
# c:\Users\Asus\100DaysML\MODELS\SingleLayerPrecepton\.venv\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
plot_decision_regions(
    x.to_numpy(), 
    y.to_numpy().astype(int), 
    clf=pr, 
    legend=2, 
    contourf_kwargs={'alpha': 0.01}
)
plt.show()
# Out:
# c:\Users\Asus\100DaysML\MODELS\SingleLayerPrecepton\.venv\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
